# %%
"""
This script gets a list of all the IDs of available services on the TOSDR API.
It then goes through the list of ids and downloads the JSON object associated with the 
service, containing its details, full text of documents, points, etc. 
The script also downloads all the cases from TOSDR

Both services and cases are inserted into a remote MongoDB instance. This means we do not
need to pass around a huge .txt file or re-scrape the data we need from the API each time 
we run a test.
"""
import requests
import json
import pprint
import time
from pymongo import MongoClient
from tqdm import tqdm

# Do pip install pymongo and pip install tqdm

ATLAS_URI="mongodb+srv://user:9ZDgfo2r3Rc6BCh6@tosleuth.mn1yhns.mongodb.net/?retryWrites=true&w=majority"
DB_NAME="tosleuth"

client = MongoClient(ATLAS_URI)
db = client[DB_NAME]

# Create collections for testing
services = db["services"]
cases = db["cases"]

# %%
# Collect all IDs of services that have been comprehensively reviewed
service_ids = []

services_endpoint = "https://api.tosdr.org/service/v2"
# Pagination is enabled on this API so we can only get 100 at a time
# Find how many pages we need first
response = requests.get(services_endpoint)
start = json.loads(response.text)["parameters"]["_page"]["start"]
end = json.loads(response.text)["parameters"]["_page"]["end"]
for i in tqdm(range(start, end+1), desc="Retrieving all service ids:"):
    response = requests.get(services_endpoint, params={"page": i})
    current_services = json.loads(response.text)["parameters"]["services"]
    # Filter services that would not offer useful data:
    # is_comprehensively_reviewed = False 
    # rating = null
    # pprint.pprint(json.loads(response.text))
    service_ids += [
        service["id"] for service in current_services
        if (
            service["is_comprehensively_reviewed"]
            and service["rating"]
        )
    ]
    # sleep so we don't get banned 
    time.sleep(2)
with open("ids.txt", "w+") as f:
    f.writelines([str(id) + "\n" for id in service_ids])

# %%
# Now we go through each service ID and get the service object, documents with full text and points to insert into the DB
# from TOSDR's old API
old_services_endpoint = "https://api.tosdr.org/service/v1/"
with open("ids.txt", "r") as f:
    service_ids = f.readlines()
    for index in tqdm(range(0, len(service_ids)), desc="Downloading service records:"):
        service_id = service_ids[index]
        # For each service_id, get the response from the API
        # print(service_id)
        response = requests.get(old_services_endpoint, params={"service": int(service_id)})
        service = json.loads(response.text)["parameters"]
        # pprint.pprint(response)
        # Insert it into MongoDB to be used later
        services.insert_one(service)
        time.sleep(1.5)
# Out:
#   Cell In[21], line 11
#     response = json.loads(response.text)[]
#                                          ^
# SyntaxError: invalid syntax

# %%
import requests
import json
from tqdm import tqdm
import pprint
# Collect all cases from TOSDR and insert them in MongoDB
cases_endpoint = "https://api.tosdr.org/case/v1/"
# Find how many pages we need first
response = requests.get(cases_endpoint)
start = json.loads(response.text)["parameters"]["_page"]["start"]
end = json.loads(response.text)["parameters"]["_page"]["end"]
for index in tqdm(range(0, end+1), desc="Downloading cases:"):
    response = requests.get(cases_endpoint, params={"page": index})
    curr_cases = json.loads(response.text)["parameters"]["cases"]
    # Insert into our database collection called "cases"
    cases.insert_many(curr_cases)
# Out:
# Downloading cases::  25%|██▌       | 1/4 [00:01<00:03,  1.15s/it]
# [{'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.452Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'You can ask the service to remove your content at any time, '
#                  "and it's deleted within a reasonable time.",
#   'id': '175',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=175'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/175',
#                         'edit': 'https://edit.tosdr.org/case/175/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/175/case_comments/new'}},
#   'title': 'You can delete your content from this service',
#   'updated_at': {'pgsql': '2021-02-27T14:23:56.238Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614435836}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.388Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'The service may still use your content and display it after '
#                  'you stopped using it by closing your account. The case '
#                  'applies to terms requiring users to grant them a perpetual '
#                  'license over that content.\r\n',
#   'id': '130',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=130'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/130',
#                         'edit': 'https://edit.tosdr.org/case/130/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/130/case_comments/new'}},
#   'title': 'A license is kept on user-generated content even after you close '
#            'your account',
#   'updated_at': {'pgsql': '2021-05-06T08:26:06.196Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620289566}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.370Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'The service may use tracking technologies in third-party '
#                  "websites to track your online activity while you aren't "
#                  'visiting their Site.\r\n',
#   'id': '129',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=129'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/129',
#                         'edit': 'https://edit.tosdr.org/case/129/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/129/case_comments/new'}},
#   'title': 'This service tracks you on other websites',
#   'updated_at': {'pgsql': '2021-02-24T22:56:35.859Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614207395}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-07-22T09:09:08.496Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1532250548},
#   'description': 'By using the service, you agree to comply with the '
#                  "applicable laws of the service's jurisdiction, regardless of "
#                  'your location.',
#   'id': '237',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=237'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/237',
#                         'edit': 'https://edit.tosdr.org/case/237/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/237/case_comments/new'}},
#   'title': "You agree to comply with the law of the service's country",
#   'updated_at': {'pgsql': '2021-05-06T08:35:07.855Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290107}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.415Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'The service may still use your content and display it after '
#                  'you stopped using it by closing your account, since you '
#                  'granted them a perpetual or (in some cases) an unlimited '
#                  'license over that content.',
#   'id': '173',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=173'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/173',
#                         'edit': 'https://edit.tosdr.org/case/173/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/173/case_comments/new'}},
#   'title': 'This service retains rights to your content even after you stop '
#            'using your account',
#   'updated_at': {'pgsql': '2021-02-27T15:51:22.501Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614441082}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.320Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'Weight was 30.',
#   'id': '169',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=169'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/169',
#                         'edit': 'https://edit.tosdr.org/case/169/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/169/case_comments/new'}},
#   'title': 'The service is transparent regarding government requests or '
#            'inquiries that may involve your data.',
#   'updated_at': {'pgsql': '2021-05-06T08:36:09.133Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290169}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.468Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '133',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=133'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/133',
#                         'edit': 'https://edit.tosdr.org/case/133/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/133/case_comments/new'}},
#   'title': 'very broad',
#   'updated_at': {'pgsql': '2020-11-12T04:15:01.495Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1605154501}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.166Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': "Payments are final and can't be refunded unless required by "
#                  'law.',
#   'id': '162',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=162'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/162',
#                         'edit': 'https://edit.tosdr.org/case/162/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/162/case_comments/new'}},
#   'title': 'The service has a no refund policy',
#   'updated_at': {'pgsql': '2021-03-27T16:43:06.005Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1616863386}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.366Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'This case applies to services under licenses that are free '
#                  'as in "freedom". According to the Free Software Foundation, '
#                  '"free software is the software that grants the user the '
#                  'freedom to share, study, and modify it". Furthermore, the '
#                  'code is entirely open source and may be used without any '
#                  'restriction, including for commercial purposes.',
#   'id': '171',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=171'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/171',
#                         'edit': 'https://edit.tosdr.org/case/171/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/171/case_comments/new'}},
#   'title': 'Features of the website are made available under a free software '
#            'license',
#   'updated_at': {'pgsql': '2021-05-04T17:54:43.907Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620150883}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-07-22T09:13:18.812Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1532250798},
#   'description': '',
#   'id': '238',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=238'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/238',
#                         'edit': 'https://edit.tosdr.org/case/238/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/238/case_comments/new'}},
#   'title': 'You agree not to submit illegal content',
#   'updated_at': {'pgsql': '2021-05-06T08:37:17.162Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290237}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.602Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'If content that you own is copied or made accessible through '
#                  'the service in a way that constitutes an intellectual '
#                  'property right infringement, you can report it following the '
#                  'instructions given in the agreements. ',
#   'id': '138',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=138'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/138',
#                         'edit': 'https://edit.tosdr.org/case/138/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/138/case_comments/new'}},
#   'title': 'Instructions are provided on how to submit a copyright claim',
#   'updated_at': {'pgsql': '2021-05-06T08:26:25.934Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620289585}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.284Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'Weight was 30.',
#   'id': '168',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=168'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/168',
#                         'edit': 'https://edit.tosdr.org/case/168/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/168/case_comments/new'}},
#   'title': 'The service is not transparent regarding government requests or '
#            'inquiries that may involve your data. ',
#   'updated_at': {'pgsql': '2021-05-06T08:34:07.393Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290047}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.563Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '136',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=136'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/136',
#                         'edit': 'https://edit.tosdr.org/case/136/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/136/case_comments/new'}},
#   'title': 'The copyright license that you grant this service is limited to '
#            "the parties that make up the service's broader platform.",
#   'updated_at': {'pgsql': '2021-05-06T08:35:01.322Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290101}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.435Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '132',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=132'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/132',
#                         'edit': 'https://edit.tosdr.org/case/132/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/132/case_comments/new'}},
#   'title': 'The copyright license maintained by the service over your data '
#            'and/or content is broader than necessary.',
#   'updated_at': {'pgsql': '2021-05-06T08:49:47.774Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290987}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.192Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'The Terms may be updated without prior notice, but users '
#                  'will be notified of the changes at the moment they will '
#                  'start applying.',
#   'id': '122',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=122'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/122',
#                         'edit': 'https://edit.tosdr.org/case/122/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/122/case_comments/new'}},
#   'title': 'The terms may be changed at any time, but you will receive '
#            'notification of the changes',
#   'updated_at': {'pgsql': '2021-05-07T16:23:11.148Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620404591}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-16T14:20:48.892Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1534429248},
#   'description': 'If you have a dispute with another user on this service, '
#                  "they can review the issue and intervene. However, they don't "
#                  'have an obligation to do so.\r\n'
#                  '\r\n',
#   'id': '276',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=276'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/276',
#                         'edit': 'https://edit.tosdr.org/case/276/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/276/case_comments/new'}},
#   'title': 'The service can intervene in user disputes',
#   'updated_at': {'pgsql': '2018-08-16T14:20:48.892Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1534429248}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-07-11T09:35:12.069Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1531301712},
#   'description': 'Do not select this case, because points with this case will '
#                  'not show up on tosdr.org',
#   'id': '235',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=235'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/235',
#                         'edit': 'https://edit.tosdr.org/case/235/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/235/case_comments/new'}},
#   'title': 'none',
#   'updated_at': {'pgsql': '2019-04-01T07:00:21.112Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1554102021}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.661Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'In this context third-parties refers to anyone including '
#                  'friends, family, or company ',
#   'id': '229',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=229'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/229',
#                         'edit': 'https://edit.tosdr.org/case/229/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/229/case_comments/new'}},
#   'title': 'You cannot distribute or disclose your account to third parties',
#   'updated_at': {'pgsql': '2020-10-19T20:27:50.912Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1603139270}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.544Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': '',
#   'id': '179',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=179'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/179',
#                         'edit': 'https://edit.tosdr.org/case/179/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/179/case_comments/new'}},
#   'title': 'This service takes credit for your content',
#   'updated_at': {'pgsql': '2018-07-19T05:51:47.534Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1531979507}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.027Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'You are responsible for the interactions and the disputes '
#                  'that may occur with other users of the Service. In the event '
#                  'of a dispute, you release the Service from all claims '
#                  'resulting from it.',
#   'id': '154',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=154'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/154',
#                         'edit': 'https://edit.tosdr.org/case/154/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/154/case_comments/new'}},
#   'title': 'This service cannot be held responsible for disputes that you may '
#            'have with other users',
#   'updated_at': {'pgsql': '2021-02-28T12:00:09.055Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614513609}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.856Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '149',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=149'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/149',
#                         'edit': 'https://edit.tosdr.org/case/149/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/149/case_comments/new'}},
#   'title': 'Any liability on behalf of the service is only limited to the fees '
#            'you paid as a user',
#   'updated_at': {'pgsql': '2021-05-31T20:20:11.273Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1622492411}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.502Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'By posting content through the Services, users grant them a '
#                  'transferable and/or sublicensable right, which allows user '
#                  'content to be licensed to third parties.',
#   'id': '134',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=134'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/134',
#                         'edit': 'https://edit.tosdr.org/case/134/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/134/case_comments/new'}},
#   'title': 'Your content can be licensed to third parties',
#   'updated_at': {'pgsql': '2021-06-05T18:04:47.563Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1622916287}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2021-02-27T09:40:23.541Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614418823},
#   'description': 'The service states that whenever it links to third party '
#                  'websites or applications, its Terms of Service does not '
#                  'apply. Those third party websites or applications hosted or '
#                  'operated by other organizations may have their Terms of '
#                  'Service.',
#   'id': '408',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=408'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/408',
#                         'edit': 'https://edit.tosdr.org/case/408/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/408/case_comments/new'}},
#   'title': 'This service informs you that its Terms of Service does not apply '
#            'to third party websites',
#   'updated_at': {'pgsql': '2021-06-05T18:05:00.172Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1622916300}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.056Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'You have the right to send a counter-notice to the service '
#                  "if you believe the content that was removed wasn't "
#                  'infringing any copyright.',
#   'id': '155',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=155'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/155',
#                         'edit': 'https://edit.tosdr.org/case/155/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/155/case_comments/new'}},
#   'title': "If you are the target of a copyright holder's take down notice, "
#            'this service gives you the opportunity to defend yourself',
#   'updated_at': {'pgsql': '2021-04-17T01:16:56.851Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1618622216}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.556Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'This applies to cases where opting out of promotional '
#                  'communications requires sending a written letter by mail or '
#                  'is otherwise more complicated and time consuming than '
#                  'necessary.',
#   'id': '224',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=224'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/224',
#                         'edit': 'https://edit.tosdr.org/case/224/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/224/case_comments/new'}},
#   'title': 'You cannot opt out of promotional communications',
#   'updated_at': {'pgsql': '2021-02-25T13:08:48.721Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614258528}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-24T00:28:50.493Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1535070530},
#   'description': 'The user agrees not to commit any unlawful acts through the '
#                  'use of the website, including the posting of illegal content '
#                  'or messaging.',
#   'id': '280',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=280'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/280',
#                         'edit': 'https://edit.tosdr.org/case/280/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/280/case_comments/new'}},
#   'title': 'You agree not to use the service for illegal purposes',
#   'updated_at': {'pgsql': '2021-05-06T08:43:36.925Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290616}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.818Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '147',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=147'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/147',
#                         'edit': 'https://edit.tosdr.org/case/147/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/147/case_comments/new'}},
#   'title': 'Defend, indemnify, hold harmless; survives termination',
#   'updated_at': {'pgsql': '2023-04-03T18:55:50.439Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1680548150}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.619Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '139',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=139'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/139',
#                         'edit': 'https://edit.tosdr.org/case/139/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/139/case_comments/new'}},
#   'title': 'Your content can be distributed through any media known now or in '
#            'the future',
#   'updated_at': {'pgsql': '2023-04-03T18:57:28.753Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1680548248}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.587Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': "It's important to know what security measures are taken to "
#                  'protect your data from unauthorized access. This case '
#                  'applies to the Agreements that precisely explain their '
#                  'security practices.',
#   'id': '226',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=226'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/226',
#                         'edit': 'https://edit.tosdr.org/case/226/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/226/case_comments/new'}},
#   'title': 'Information is provided about security practices',
#   'updated_at': {'pgsql': '2021-05-06T08:01:23.191Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620288083}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.583Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'You have the right to choose or change the copyright license '
#                  'over content you publish through the Service.',
#   'id': '137',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=137'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/137',
#                         'edit': 'https://edit.tosdr.org/case/137/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/137/case_comments/new'}},
#   'title': 'You are free to choose the type of copyright license that you want '
#            'to use over your content',
#   'updated_at': {'pgsql': '2021-05-06T08:37:48.176Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290268}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.305Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': "You must provide your legal name and pseudonyms aren't "
#                  "allowed. This case doesn't apply to Services for which "
#                  'transparency regarding users identities is relevant for '
#                  'their purposes.',
#   'id': '214',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=214'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/214',
#                         'edit': 'https://edit.tosdr.org/case/214/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/214/case_comments/new'}},
#   'title': 'You must provide your legal name, pseudonyms are not allowed',
#   'updated_at': {'pgsql': '2021-02-25T18:48:05.605Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614278885}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.522Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'You have the right to choose or change the license over '
#                  'content you publish through the Service.',
#   'id': '222',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=222'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/222',
#                         'edit': 'https://edit.tosdr.org/case/222/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/222/case_comments/new'}},
#   'title': 'You can choose the copyright license',
#   'updated_at': {'pgsql': '2021-02-27T16:19:55.044Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1614442795}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.727Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': "Users can't use the Service for commercial purposes (unless "
#                  'the Service consents): it is only for personal, individual '
#                  'purposes.',
#   'id': '143',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=143'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/143',
#                         'edit': 'https://edit.tosdr.org/case/143/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/143/case_comments/new'}},
#   'title': 'This service is only available for use individually and '
#            'non-commercially.',
#   'updated_at': {'pgsql': '2021-03-27T16:39:13.716Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1616863153}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.695Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': 'This applies to cases where obtaining personal data requires '
#                  'sending a written letter by mail or is otherwise more '
#                  'complicated and time consuming than necessary.',
#   'id': '141',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=141'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/141',
#                         'edit': 'https://edit.tosdr.org/case/141/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/141/case_comments/new'}},
#   'title': 'Inconvenient process for obtaining personal data',
#   'updated_at': {'pgsql': '2021-03-15T19:38:02.904Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1615837082}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.619Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'The Privacy Policy explains the purposes for which data is '
#                  'collected and the way it is processed, used and shared.',
#   'id': '227',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=227'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/227',
#                         'edit': 'https://edit.tosdr.org/case/227/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/227/case_comments/new'}},
#   'title': 'Information is provided about how your personal data is used',
#   'updated_at': {'pgsql': '2021-05-06T08:00:39.315Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620288039}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.452Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'Your Personal Information is traded and shared with '
#                  'advertising companies to target ads on you, either on the '
#                  'website you were visiting or in third party websites. Your '
#                  'interaction with the service and data you have shared with '
#                  'them may be gathered to create an advertising ID or profile.',
#   'id': '220',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=220'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/220',
#                         'edit': 'https://edit.tosdr.org/case/220/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/220/case_comments/new'}},
#   'title': 'Your personal data is used to employ targeted third-party '
#            'advertising',
#   'updated_at': {'pgsql': '2021-05-06T08:29:30.145Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620289770}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.335Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '127',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=127'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/127',
#                         'edit': 'https://edit.tosdr.org/case/127/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/127/case_comments/new'}},
#   'title': 'Third party cookies are employed, but with opt out instructions',
#   'updated_at': {'pgsql': '2021-05-06T08:26:54.572Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620289614}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.275Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': "You must provide your legal name and pseudonyms aren't "
#                  'allowed, but it makes sense for the purposes of this '
#                  'service.',
#   'id': '213',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=213'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/213',
#                         'edit': 'https://edit.tosdr.org/case/213/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/213/case_comments/new'}},
#   'title': 'You are not allowed to use pseudonyms, as trust and transparency '
#            'between users regarding their identities is relevant to the '
#            'service.',
#   'updated_at': {'pgsql': '2021-05-06T08:42:16.902Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290536}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.234Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': '',
#   'id': '212',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=212'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/212',
#                         'edit': 'https://edit.tosdr.org/case/212/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/212/case_comments/new'}},
#   'title': "Pseudonyms are allowed due to the service's billing policies",
#   'updated_at': {'pgsql': '2021-05-06T08:50:20.988Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620291020}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.686Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': '',
#   'id': '231',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=231'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/231',
#                         'edit': 'https://edit.tosdr.org/case/231/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/231/case_comments/new'}},
#   'title': 'You are informed about the risk of publishing personal info online',
#   'updated_at': {'pgsql': '2021-05-06T08:37:31.235Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290251}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-21T09:47:56.311Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1534844876},
#   'description': "When you're not logged in to a service, but use it "
#                  'repeatedly, it may still feel weird that their terms and '
#                  'conditions can change between one use and the next. However, '
#                  'this does not violate the rule-of-thumb that each new '
#                  'version should be accepted from scratch, without inferring '
#                  'your acceptance from the acceptance of an earlier version. '
#                  'Since no acceptance is inferred from continued use, but only '
#                  'from current use, we rate this as neutral instead of bad.',
#   'id': '277',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=277'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/277',
#                         'edit': 'https://edit.tosdr.org/case/277/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/277/case_comments/new'}},
#   'title': 'Conditions may change, but your continued acceptance is not '
#            'inferred from an earlier acceptance',
#   'updated_at': {'pgsql': '2019-04-10T09:43:47.943Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1554889427}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-08-24T05:31:18.691Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1535088678},
#   'description': "Users are asked not to interfere with another person't "
#                  'enjoyment in using the service.\r\n'
#                  'However, this statement is very vague and open to '
#                  'interpretation by the service itself.',
#   'id': '285',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=285'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/285',
#                         'edit': 'https://edit.tosdr.org/case/285/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/285/case_comments/new'}},
#   'title': "You shall not interfere with another person's enjoyment of the "
#            'service',
#   'updated_at': {'pgsql': '2021-05-06T08:40:39.091Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290439}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-22T10:01:05.829Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1534932065},
#   'description': '',
#   'id': '278',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=278'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/278',
#                         'edit': 'https://edit.tosdr.org/case/278/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/278/case_comments/new'}},
#   'title': 'The service is not responsible for linked or (clearly) quoted '
#            'content from third-party content providers',
#   'updated_at': {'pgsql': '2018-08-22T10:01:05.829Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1534932065}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-24T05:24:43.733Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1535088283},
#   'description': 'The service does not allow any attempts at hacking or '
#                  "otherwise gaining unauthorized access to other users' "
#                  'computers.',
#   'id': '284',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=284'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/284',
#                         'edit': 'https://edit.tosdr.org/case/284/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/284/case_comments/new'}},
#   'title': 'You are prohibited from attempting to gain unauthorized access to '
#            'other computer systems',
#   'updated_at': {'pgsql': '2021-05-06T08:43:17.982Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620290597}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.635Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': '',
#   'id': '184',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=184'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/184',
#                         'edit': 'https://edit.tosdr.org/case/184/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/184/case_comments/new'}},
#   'title': 'This service provides a way for you to export your data',
#   'updated_at': {'pgsql': '2021-03-27T16:43:51.863Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1616863431}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.802Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'Users have the right to access personal data hold by the '
#                  'Service, correct it and/or permanently delete it. This '
#                  'usually applies to Services GDPR compliants. ',
#   'id': '195',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=195'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/195',
#                         'edit': 'https://edit.tosdr.org/case/195/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/195/case_comments/new'}},
#   'title': 'You can request access, correction and/or deletion of your data',
#   'updated_at': {'pgsql': '2021-03-15T19:39:19.351Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1615837159}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.894Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'The user may need to read additional product-specific '
#                  'agreements depending on the way the service is used.',
#   'id': '200',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=200'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/200',
#                         'edit': 'https://edit.tosdr.org/case/200/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/200/case_comments/new'}},
#   'title': 'Separate policies are employed for different parts of the service',
#   'updated_at': {'pgsql': '2021-05-14T12:48:24.407Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620996504}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.674Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'You must provide the service with your information in order '
#                  'to use it',
#   'id': '230',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=230'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/230',
#                         'edit': 'https://edit.tosdr.org/case/230/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/230/case_comments/new'}},
#   'title': 'You must create an account to use this service',
#   'updated_at': {'pgsql': '2021-05-14T14:37:23.623Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1621003043}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.755Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'The Service disclaims that IP adresses from users are not '
#                  'collected (or anonymized) nor shared.',
#   'id': '192',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=192'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/192',
#                         'edit': 'https://edit.tosdr.org/case/192/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/192/case_comments/new'}},
#   'title': 'IP addresses of website visitors are not tracked',
#   'updated_at': {'pgsql': '2021-05-31T20:20:49.018Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1622492449}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.915Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'At any time, your account can be terminated without '
#                  'explanation and without warning by the service. ',
#   'id': '201',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=201'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/201',
#                         'edit': 'https://edit.tosdr.org/case/201/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/201/case_comments/new'}},
#   'title': 'Your account can be deleted without prior notice and without a '
#            'reason',
#   'updated_at': {'pgsql': '2021-05-31T20:24:53.827Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1622492693}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.118Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': 'Users will be notified before their experience is impacted '
#                  'due to website maintenance.',
#   'id': '159',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=159'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/159',
#                         'edit': 'https://edit.tosdr.org/case/159/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/159/case_comments/new'}},
#   'title': 'You will be notified about website maintenance',
#   'updated_at': {'pgsql': '2021-05-06T08:14:33.371Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620288873}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2018-09-04T13:43:38.325Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1536068618},
#   'description': "The service's terms explain they may change or remove "
#                  'usernames at their sole discretion, and they may do so '
#                  'without prior notice.',
#   'id': '328',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=328'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/328',
#                         'edit': 'https://edit.tosdr.org/case/328/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/328/case_comments/new'}},
#   'title': 'Usernames can be rejected or changed for any reason',
#   'updated_at': {'pgsql': '2021-03-27T16:58:50.185Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1616864330}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.258Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': '',
#   'id': '167',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=167'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/167',
#                         'edit': 'https://edit.tosdr.org/case/167/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/167/case_comments/new'}},
#   'title': 'Third parties are not allowed to access your personal information '
#            'without a legal basis',
#   'updated_at': {'pgsql': '2021-05-06T08:03:57.813Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1620288237}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:09.988Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116369},
#   'description': '',
#   'id': '205',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=205'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/205',
# ...
#   'id': '501',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=501'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/501',
#                         'edit': 'https://edit.tosdr.org/case/501/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/501/case_comments/new'}},
#   'title': 'This Service does not keep any logs.',
#   'updated_at': {'pgsql': '2023-01-12T12:31:05.922Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1673526665}},
#  {'classification': {'hex': 0, 'human': 'blocker'},
#   'created_at': {'pgsql': '2023-02-01T13:52:02.496Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1675259522},
#   'description': 'This service requires that your behavior, and/or content, '
#                  'complies with the newest version of the regulations '
#                  'regardless of the time at which you have submitted it.',
#   'id': '502',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=502'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/502',
#                         'edit': 'https://edit.tosdr.org/case/502/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/502/case_comments/new'}},
#   'title': 'Changes in policies are applied retroactively.',
#   'updated_at': {'pgsql': '2023-02-01T13:52:02.496Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1675259522}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-01-16T15:26:08.798Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116368},
#   'description': '',
#   'id': '146',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=146'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/146',
#                         'edit': 'https://edit.tosdr.org/case/146/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/146/case_comments/new'}},
#   'title': 'You agree to defend, indemnify, and hold the service harmless in '
#            'case of a claim related to your use of the service',
#   'updated_at': {'pgsql': '2023-04-03T18:50:27.070Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1680547827}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-08-26T22:31:46.138Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1535322706},
#   'description': 'The service assumes no liability for any damages the user '
#                  'incurs, including tangible (e.g. profits) and intangible '
#                  'losses (e.g. data), resulting from the use or inability to '
#                  'use the service or any other matter relating to the service.',
#   'id': '293',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=293'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/293',
#                         'edit': 'https://edit.tosdr.org/case/293/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/293/case_comments/new'}},
#   'title': 'This service assumes no liability for any losses or damages '
#            'resulting from any matter relating to the service',
#   'updated_at': {'pgsql': '2023-04-03T18:56:40.248Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1680548200}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2018-01-16T15:26:10.631Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1516116370},
#   'description': 'The Privacy Policy describes in detail the data collected '
#                  'through the website and through the services provided.',
#   'id': '228',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=228'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/228',
#                         'edit': 'https://edit.tosdr.org/case/228/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/228/case_comments/new'}},
#   'title': 'Information is provided about what kind of information they '
#            'collect',
#   'updated_at': {'pgsql': '2023-04-09T10:59:47.874Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1681037987}},
#  {'classification': {'hex': 0, 'human': 'blocker'},
#   'created_at': {'pgsql': '2023-05-20T20:14:57.173Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1684613697},
#   'description': 'Personal data or content you share with the service may be '
#                  'processed to make decisions by automated means without human '
#                  'involvement. This includes profiling, which is any form of '
#                  'automated processing of your information to analyse or '
#                  'predict things like your economic situation, health, '
#                  'personal preferences or interests; as well as Artificial '
#                  'Intelligence training.',
#   'id': '504',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=504'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/504',
#                         'edit': 'https://edit.tosdr.org/case/504/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/504/case_comments/new'}},
#   'title': 'Your personal data is used for automated decision-making, '
#            'profiling or AI training',
#   'updated_at': {'pgsql': '2023-05-20T20:14:57.173Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1684613697}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2018-06-26T12:04:59.070Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1530014699},
#   'description': 'Even though the Do Not Track (DNT) header was not '
#                  'implemented perfectly, services should not track users whose '
#                  'browsers send a DNT header.',
#   'id': '233',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=233'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/233',
#                         'edit': 'https://edit.tosdr.org/case/233/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/233/case_comments/new'}},
#   'title': 'Do Not Track (DNT) headers are ignored and you are tracked anyway '
#            'even if you set this header.',
#   'updated_at': {'pgsql': '2023-09-19T15:25:11.685Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1695137111}},
#  {'classification': {'hex': 0, 'human': 'good'},
#   'created_at': {'pgsql': '2023-11-17T19:31:35.986Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1700249495},
#   'description': 'When an organisation trains its staff regarding data, this '
#                  'should be regarded as a positive as it shows they are '
#                  'careful and helps staff to understand how to handle data.',
#   'id': '505',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=505'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/505',
#                         'edit': 'https://edit.tosdr.org/case/505/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/505/case_comments/new'}},
#   'title': 'Staff at this organisation recieve training about handling data',
#   'updated_at': {'pgsql': '2023-11-17T19:31:35.986Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1700249495}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2020-12-30T03:17:35.286Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1609298255},
#   'description': 'The Service infers your acceptance from your continued '
#                  'usage, instead of prompting you to read the new Terms and '
#                  'asking for direct consent. This doesn’t apply to services '
#                  'that have no way to seek consent from users through their '
#                  'contact details or an account.',
#   'id': '403',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=403'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/403',
#                         'edit': 'https://edit.tosdr.org/case/403/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/403/case_comments/new'}},
#   'title': 'Instead of asking directly, this Service will assume your consent '
#            'to changes of terms merely from your usage.',
#   'updated_at': {'pgsql': '2023-11-17T19:55:41.476Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1700250941}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2024-01-16T19:35:44.151Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433744},
#   'description': 'Desirable information, not core requirement according to the '
#                  'GDPR, this should be provided by the edtech vendor (when it '
#                  'comes to education technologies targeting students)',
#   'id': '506',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=506'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/506',
#                         'edit': 'https://edit.tosdr.org/case/506/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/506/case_comments/new'}},
#   'title': 'the policy version has a clear date',
#   'updated_at': {'pgsql': '2024-01-16T19:35:44.151Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433744}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2024-01-16T19:36:44.958Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433804},
#   'description': 'Desirable information, not core requirement according to the '
#                  'GDPR, to be had in the policies of edtech vendors targeting '
#                  'students/children.',
#   'id': '507',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=507'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/507',
#                         'edit': 'https://edit.tosdr.org/case/507/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/507/case_comments/new'}},
#   'title': 'a changelog or past policy versions are available for review',
#   'updated_at': {'pgsql': '2024-01-16T19:36:44.958Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433804}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2024-01-16T19:37:25.778Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433845},
#   'description': 'Desirable, not core to the GDPR requirements, for edtech '
#                  'vendors to have as information in their policies.',
#   'id': '508',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=508'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/508',
#                         'edit': 'https://edit.tosdr.org/case/508/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/508/case_comments/new'}},
#   'title': 'users are notified of any material changes',
#   'updated_at': {'pgsql': '2024-01-16T19:37:25.778Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433845}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2024-01-16T19:37:56.114Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433876},
#   'description': '',
#   'id': '509',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=509'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/509',
#                         'edit': 'https://edit.tosdr.org/case/509/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/509/case_comments/new'}},
#   'title': 'users can contact the (edtech) vendor about any privacy policy '
#            'questions, complaints, and material changes as indicated in the '
#            'policies',
#   'updated_at': {'pgsql': '2024-01-16T19:37:56.114Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433876}},
#  {'classification': {'hex': 0, 'human': ''},
#   'created_at': {'pgsql': '2024-01-16T19:38:47.190Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433927},
#   'description': '',
#   'id': '510',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=510'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/510',
#                         'edit': 'https://edit.tosdr.org/case/510/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/510/case_comments/new'}},
#   'title': 'the products can be used by teachers',
#   'updated_at': {'pgsql': '2024-01-16T19:38:47.190Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433927}},
#  {'classification': {'hex': 0, 'human': 'neutral'},
#   'created_at': {'pgsql': '2024-01-16T19:39:21.904Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433961},
#   'description': 'Desirable/ideal to have as information in the policies.',
#   'id': '511',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=511'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/511',
#                         'edit': 'https://edit.tosdr.org/case/511/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/511/case_comments/new'}},
#   'title': 'the products can be used by parents or guardians',
#   'updated_at': {'pgsql': '2024-01-16T19:39:21.904Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705433961}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2024-01-16T19:40:03.561Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434003},
#   'description': 'Required to specify according to the GDPR',
#   'id': '512',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=512'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/512',
#                         'edit': 'https://edit.tosdr.org/case/512/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/512/case_comments/new'}},
#   'title': 'biometric data is collected',
#   'updated_at': {'pgsql': '2024-01-16T19:40:03.561Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434003}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2024-01-16T19:40:48.436Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434048},
#   'description': 'Required by the GDPR to be clearly explained in the policy.',
#   'id': '513',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=513'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/513',
#                         'edit': 'https://edit.tosdr.org/case/513/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/513/case_comments/new'}},
#   'title': 'behavioral data is collected',
#   'updated_at': {'pgsql': '2024-01-16T19:40:48.436Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434048}},
#  {'classification': {'hex': 0, 'human': 'bad'},
#   'created_at': {'pgsql': '2024-01-16T19:41:12.682Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434072},
#   'description': 'Required by the GDPR to be in the policy',
#   'id': '514',
#   'links': {'crisp': {'api': 'https://api.tosdr.org/case/v1/?case=514'},
#             'phoenix': {'case': 'https://edit.tosdr.org/case/514',
#                         'edit': 'https://edit.tosdr.org/case/514/edit',
#                         'new_comment': 'https://edit.tosdr.org/case/514/case_comments/new'}},
#   'title': 'sensitive personal information is collected',
#   'updated_at': {'pgsql': '2024-01-16T19:41:12.682Z',
#                  'timezone': 'Europe/Berlin',
#                  'unix': 1705434072}}]
